# %%
names = ["Recep", "Ayse", "Fatma"] #iterable

for n in names:
    print(f"Hello I am {n}")
    print(f"Hello, {n} nice to meet you")
    print(f"Did you {n}?")
# Out:
# Hello I am Recep
# Hello, Recep nice to meet you
# Did you Recep?
# Hello I am Ayse
# Hello, Ayse nice to meet you
# Did you Ayse?
# Hello I am Fatma
# Hello, Fatma nice to meet you
# Did you Fatma?

# %%
count = 0

while count < 10:
    print(f"I am counting {count}")
    count = count + 1
# Out:
# I am counting 0
# I am counting 1
# I am counting 2
# I am counting 3
# I am counting 4
# I am counting 5
# I am counting 6
# I am counting 7
# I am counting 8
# I am counting 9

# %%
def toplama(a: int | float, b: int | float) -> int | float:
    c = a + b
    return c 

def listeyi_topla(sayi_listesi: list) -> list:
    bos_liste = []

    for i in range(0, len(sayi_listesi), 2):
        c = toplama(sayi_listesi[i], sayi_listesi[i+1])
        bos_liste.append(c)
    
    return bos_liste

# %%
listemiz = [4, 5, 8, 5.6, 5, 7.67]

result = 0

for sayi in listemiz:
    result += sayi

print(result)
# Out:
# 35.27

# %%
listeyi_topla(listemiz)
# Out:
# [9, 13.6, 12.67]

# %%
for i, j in enumerate(listemiz):
    print(i, j)
# Out:
# 0 4
# 1 5
# 2 8
# 3 5.6
# 4 5
# 5 7.67

# %%
list(range(0, len(listemiz), 2))
# Out:
# [0, 2, 4]

# %%
for i in range(0, len(listemiz), 2):
    c = toplama(listemiz[i], listemiz[i+1])
    print(c)
# Out:
# 9
# 13.6
# 12.67
